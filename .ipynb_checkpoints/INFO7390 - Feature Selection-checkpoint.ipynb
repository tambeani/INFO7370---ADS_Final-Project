# %% [markdown]
# # INFO7390 - Advance Data Science and Architecture
#
# ## Project Title: Job Recommendation System
# ### Teammates:
# 1. Aniruddha Tambe
# 2. Shubhankar Salvi
# 3. Sangram Vuppula

# %% [markdown]
# ## Importing packages:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import missingno as msno
from icecream import ic
import os
import re
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import plotly.figure_factory as ff
from kaleido.scopes.plotly import PlotlyScope
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_selection import SelectKBest
import warnings
warnings.filterwarnings(action='ignore')
pd.options.display.max_columns = 100

# plotly settings and functions
scope = PlotlyScope(plotlyjs="https://cdn.plot.ly/plotly-latest.min.js")
pio.templates.default = 'plotly_white'

# %% [markdown]
# ## Dataset:
#
# 1. Stack Overflow 2018 Developer Survey - Individual responses on the 2018 Developer Survey fielded by Stack Overflow
#
# https://www.kaggle.com/stackoverflow/stack-overflow-2018-developer-survey#survey_results_public.csv
#
# 2. U.S. Technology Jobs on Dice.com - 22,000 US-based Technology Job Listings
#
# https://www.kaggle.com/PromptCloudHQ/us-technology-jobs-on-dicecom

# %%
survey = pd.read_csv("./dataset/survey_results_public.csv")

# %% [markdown]
# ## Preliminary data summary

# %%
# List all column names
all_col_names = survey.columns.values.tolist()
print('Number of columns: ',len(all_col_names))
#print(all_col_names)
# Out:
# Number of columns:  129

# %%
# Get categorical columns
cat_cols = [col for col in survey.columns if survey[col].dtype.name=="object"]
float_cols = [col for col in survey.columns if survey[col].dtype.name=="float64"]
int_cols = [col for col in survey.columns if survey[col].dtype.name=="int64"]
print('Number of categorical columns: ',len(cat_cols))
print('Number of float columns: ',len(float_cols))
print('Number of int columns: ',len(int_cols))
# Out:
# Number of categorical columns:  87
# Number of float columns:  41
# Number of int columns:  1

# %% [markdown]
# ## Findings
#
# 1. Number of categorical columns:  87
# 2. Number of float columns:  41
# 3. Number of int columns:  1
# 4. Datatypes found: float64(41), int64(1), object(87)
# 5. Rows x Columns: 98855 x 129

# %% [markdown]
# ## Dropping irrelevant columns

# %%
attrToDrop=[]
survey=survey[survey.columns.difference(attrToDrop)]
print("Number of columns dropped: ",len(attrToDrop))
# Out:
# Number of columns dropped:  102

# %%
# Get categorical columns
cat_cols = [col for col in survey.columns if survey[col].dtype.name=="object"]
float_cols = [col for col in survey.columns if survey[col].dtype.name=="float64"]
int_cols = [col for col in survey.columns if survey[col].dtype.name=="int64"]
print('Number of categorical columns: ',len(cat_cols))
print('Number of float columns: ',len(float_cols))
print('Number of int columns: ',len(int_cols))
print('Total number of columns: ',len(survey.columns))
# Out:
# Number of categorical columns:  43
# Number of float columns:  29
# Number of int columns:  1
# Total number of columns:  73

# %% [markdown]
# ## Export survey to csv

# %%
survey.to_csv('./dataset/survey_dropped_columns.csv',index=False)

# %% [markdown]
# ## Survey

# %%
survey.head(10)
# Out:
#                  Age  AgreeDisagree1              AgreeDisagree2  \
# 0  25 - 34 years old  Strongly agree              Strongly agree
# 1  35 - 44 years old           Agree                       Agree
# 2                NaN             NaN                         NaN
# 3  35 - 44 years old        Disagree                    Disagree
# 4  18 - 24 years old  Strongly agree                       Agree
# 5  18 - 24 years old        Disagree  Neither Agree nor Disagree
# 6  18 - 24 years old        Disagree                       Agree
# 7  25 - 34 years old  Strongly agree           Strongly disagree
# 8  35 - 44 years old  Strongly agree           Strongly disagree
# 9                NaN             NaN                         NaN
#
#                AgreeDisagree3  AssessBenefits1  AssessBenefits10  \
# 0  Neither Agree nor Disagree              NaN               NaN
# 1  Neither Agree nor Disagree              1.0               2.0
# 2                         NaN              NaN               NaN
# 3           Strongly disagree              NaN               NaN
# 4           Strongly disagree              1.0               9.0
# 5           Strongly disagree              1.0               7.0
# 6           Strongly disagree              1.0              10.0
# 7  Neither Agree nor Disagree              1.0              10.0
# 8           Strongly disagree              1.0               7.0
# 9                         NaN              NaN               NaN
#
#    AssessBenefits11  AssessBenefits2  AssessBenefits3  AssessBenefits4  \
# 0               NaN              NaN              NaN              NaN
# 1               8.0              5.0              3.0              7.0
# 2               NaN              NaN              NaN              NaN
# 3               NaN              NaN              NaN              NaN
# 4               6.0             10.0              2.0              4.0
# 5               8.0              3.0              4.0             10.0
# 6               5.0              3.0              2.0              9.0
# 7               8.0              3.0              5.0              7.0
# 8               6.0              3.0              2.0              9.0
# 9               NaN              NaN              NaN              NaN
#
#    AssessBenefits5  AssessBenefits6  AssessBenefits7  AssessBenefits8  \
# 0              NaN              NaN              NaN              NaN
# 1             10.0              4.0             11.0              9.0
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              8.0              3.0             11.0              7.0
# 5              9.0              2.0              6.0              5.0
# 6             11.0              4.0              8.0              6.0
# 7              6.0              2.0             11.0              9.0
# 8             11.0              5.0              8.0              4.0
# 9              NaN              NaN              NaN              NaN
#
#    AssessBenefits9  AssessJob1  AssessJob10  AssessJob2  AssessJob3  \
# 0              NaN        10.0          6.0         7.0         8.0
# 1              6.0         1.0          9.0         7.0        10.0
# 2              NaN         NaN          NaN         NaN         NaN
# 3              NaN         NaN          NaN         NaN         NaN
# 4              5.0         8.0          9.0         5.0         7.0
# 5             11.0         8.0          7.0         5.0         4.0
# 6              7.0         5.0          6.0         3.0         9.0
# 7              4.0         6.0          3.0         5.0         4.0
# 8             10.0         6.0          2.0         3.0         7.0
# 9              NaN         NaN          NaN         NaN         NaN
#
#    AssessJob4  AssessJob5  AssessJob6  AssessJob7  AssessJob8  AssessJob9  \
# 0         1.0         2.0         5.0         3.0         4.0         9.0
# 1         8.0         2.0         5.0         4.0         3.0         6.0
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         1.0         2.0         6.0         4.0         3.0        10.0
# 5         9.0         1.0         3.0         6.0         2.0        10.0
# 6         4.0         1.0         8.0         2.0         7.0        10.0
# 7         2.0         7.0         8.0        10.0         1.0         9.0
# 8         4.0         1.0         5.0        10.0         8.0         9.0
# 9         NaN         NaN         NaN         NaN         NaN         NaN
#
#                    CareerSatisfaction  \
# 0                 Extremely satisfied
# 1  Neither satisfied nor dissatisfied
# 2                Moderately satisfied
# 3               Slightly dissatisfied
# 4                Moderately satisfied
# 5                  Slightly satisfied
# 6                Moderately satisfied
# 7                Moderately satisfied
# 8                Moderately satisfied
# 9                                 NaN
#
#                                   CommunicationTools  \
# 0                                              Slack
# 1  Confluence;Office / productivity suite (Micros...
# 2                                                NaN
# 3                                                NaN
# 4  Office / productivity suite (Microsoft Office,...
# 5  Confluence;Jira;Office / productivity suite (M...
# 6  Confluence;Office / productivity suite (Micros...
# 7  Facebook;Google Hangouts/Chat;Office / product...
# 8  Confluence;HipChat;Jira;Office / productivity ...
# 9                                                NaN
#
#                 CompanySize  ConvertedSalary         Country  \
# 0        20 to 99 employees              NaN           Kenya
# 1  10,000 or more employees          70841.0  United Kingdom
# 2        20 to 99 employees              NaN   United States
# 3      100 to 499 employees              NaN   United States
# 4  10,000 or more employees          21426.0    South Africa
# 5        10 to 19 employees          41671.0  United Kingdom
# 6  10,000 or more employees         120000.0   United States
# 7        10 to 19 employees              NaN         Nigeria
# 8      100 to 499 employees         250000.0   United States
# 9      500 to 999 employees              NaN           India
#
#                       Currency CurrencySymbol  \
# 0                          NaN            KES
# 1  British pounds sterling (£)            GBP
# 2                          NaN            NaN
# 3             U.S. dollars ($)            NaN
# 4      South African rands (R)            ZAR
# 5  British pounds sterling (£)            GBP
# 6             U.S. dollars ($)            USD
# 7                          NaN            NaN
# 8             U.S. dollars ($)            USD
# 9                          NaN            NaN
#
#                               DatabaseDesireNextYear  \
# 0  Redis;SQL Server;MySQL;PostgreSQL;Amazon RDS/A...
# 1                                         PostgreSQL
# 2                                                NaN
# 3  SQL Server;Microsoft Azure (Tables, CosmosDB, ...
# 4                          PostgreSQL;Oracle;IBM Db2
# 5                                         PostgreSQL
# 6                                                NaN
# 7                                                NaN
# 8  Redis;PostgreSQL;Amazon DynamoDB;Apache Hive;A...
# 9                                                NaN
#
#                                   DatabaseWorkedWith Dependents  \
# 0  Redis;SQL Server;MySQL;PostgreSQL;Amazon RDS/A...        Yes
# 1                         Redis;PostgreSQL;Memcached        Yes
# 2                                                NaN        NaN
# 3  SQL Server;Microsoft Azure (Tables, CosmosDB, ...         No
# 4               SQL Server;PostgreSQL;Oracle;IBM Db2        Yes
# 5                                            MongoDB         No
# 6                                            MongoDB         No
# 7  MongoDB;MySQL;Microsoft Azure (Tables, CosmosD...         No
# 8  Redis;PostgreSQL;Amazon DynamoDB;Apache HBase;...        Yes
# 9                                                NaN        NaN
#
#                                              DevType  \
# 0                               Full-stack developer
# 1  Database administrator;DevOps specialist;Full-...
# 2           Engineering manager;Full-stack developer
# 3                               Full-stack developer
# 4  Data or business analyst;Desktop or enterprise...
# 5  Back-end developer;Database administrator;Fron...
# 6  Back-end developer;Front-end developer;Full-st...
# 7  Designer;Front-end developer;QA or test developer
# 8  Back-end developer;C-suite executive (CEO, CTO...
# 9                                           Designer
#
#                                       EducationTypes          Employment  \
# 0  Taught yourself a new language, framework, or ...  Employed part-time
# 1  Taught yourself a new language, framework, or ...  Employed full-time
# 2                                                NaN  Employed full-time
# 3  Completed an industry certification program (e...  Employed full-time
# 4  Taken a part-time in-person course in programm...  Employed full-time
# 5  Received on-the-job training in software devel...  Employed full-time
# 6  Received on-the-job training in software devel...  Employed full-time
# 7  Taken an online course in programming or softw...  Employed full-time
# 8  Taken an online course in programming or softw...  Employed full-time
# 9                                                NaN  Employed full-time
#
#                                      FormalEducation  FrameworkDesireNextYear  \
# 0           Bachelor’s degree (BA, BS, B.Eng., etc.)             Django;React
# 1           Bachelor’s degree (BA, BS, B.Eng., etc.)                    React
# 2                                   Associate degree                      NaN
# 3           Bachelor’s degree (BA, BS, B.Eng., etc.)  Angular;.NET Core;React
# 4  Some college/university study without earning ...                      NaN
# 5           Bachelor’s degree (BA, BS, B.Eng., etc.)                  Node.js
# 6  Some college/university study without earning ...         React;TensorFlow
# 7           Bachelor’s degree (BA, BS, B.Eng., etc.)         .NET Core;Django
# 8  Some college/university study without earning ...                      NaN
# 9           Bachelor’s degree (BA, BS, B.Eng., etc.)                      NaN
#
#           FrameworkWorkedWith  Gender  \
# 0                Django;React    Male
# 1                      Django    Male
# 2                         NaN     NaN
# 3                         NaN    Male
# 4                         NaN    Male
# 5             Angular;Node.js    Male
# 6               Node.js;React    Male
# 7             Angular;Node.js  Female
# 8  Hadoop;Node.js;React;Spark    Male
# 9                         NaN     NaN
#
#                                        HopeFiveYears  HoursComputer  \
# 0  Working as a founder or co-founder of my own c...   9 - 12 hours
# 1  Working in a different or more specialized tec...    5 - 8 hours
# 2  Working as a founder or co-founder of my own c...            NaN
# 3  Working as a founder or co-founder of my own c...   9 - 12 hours
# 4  Working in a different or more specialized tec...  Over 12 hours
# 5  Working in a different or more specialized tec...   9 - 12 hours
# 6  Working as a founder or co-founder of my own c...  Over 12 hours
# 7  Working as a founder or co-founder of my own c...  Over 12 hours
# 8                                Doing the same work   9 - 12 hours
# 9                                                NaN            NaN
#
#                                               IDE  JobEmailPriorities1  \
# 0                   Komodo;Vim;Visual Studio Code                  5.0
# 1              IPython / Jupyter;Sublime Text;Vim                  1.0
# 2                                             NaN                  NaN
# 3                Visual Studio;Visual Studio Code                  NaN
# 4      Notepad++;Visual Studio;Visual Studio Code                  7.0
# 5             IntelliJ;PyCharm;Visual Studio Code                  2.0
# 6                         Atom;Visual Studio Code                  1.0
# 7  Atom;Notepad++;Sublime Text;Visual Studio Code                  2.0
# 8               IntelliJ;PyCharm;Sublime Text;Vim                  3.0
# 9                                             NaN                  NaN
#
#    JobEmailPriorities2  JobEmailPriorities3  JobEmailPriorities4  \
# 0                  6.0                  7.0                  2.0
# 1                  3.0                  4.0                  5.0
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  3.0                  6.0                  2.0
# 5                  6.0                  7.0                  3.0
# 6                  5.0                  3.0                  4.0
# 7                  6.0                  1.0                  3.0
# 8                  7.0                  2.0                  4.0
# 9                  NaN                  NaN                  NaN
#
#    JobEmailPriorities5  JobEmailPriorities6  JobEmailPriorities7  \
# 0                  1.0                  4.0                  3.0
# 1                  2.0                  6.0                  7.0
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  1.0                  4.0                  5.0
# 5                  1.0                  5.0                  4.0
# 6                  2.0                  6.0                  7.0
# 7                  7.0                  5.0                  4.0
# 8                  1.0                  6.0                  5.0
# 9                  NaN                  NaN                  NaN
#
#                       JobSatisfaction  \
# 0                 Extremely satisfied
# 1             Moderately dissatisfied
# 2                Moderately satisfied
# 3  Neither satisfied nor dissatisfied
# 4                  Slightly satisfied
# 5                Moderately satisfied
# 6                  Slightly satisfied
# 7                  Slightly satisfied
# 8                Moderately satisfied
# 9                                 NaN
#
#                                      JobSearchStatus  \
# 0  I’m not actively looking, but I am open to new...
# 1                    I am actively looking for a job
# 2  I’m not actively looking, but I am open to new...
# 3  I’m not actively looking, but I am open to new...
# 4  I’m not actively looking, but I am open to new...
# 5                    I am actively looking for a job
# 6  I’m not actively looking, but I am open to new...
# 7  I’m not actively looking, but I am open to new...
# 8  I’m not actively looking, but I am open to new...
# 9                                                NaN
#
#                               LanguageDesireNextYear  \
# 0                         JavaScript;Python;HTML;CSS
# 1                                          Go;Python
# 2                                                NaN
# 3   C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell
# 4               Assembly;C;C++;Matlab;SQL;Bash/Shell
# 5  C#;Go;Java;JavaScript;Python;SQL;TypeScript;HT...
# 6                    C;Go;JavaScript;Python;HTML;CSS
# 7                       Matlab;SQL;Kotlin;Bash/Shell
# 8                          Erlang;Go;Python;Rust;SQL
# 9                                                NaN
#
#                                   LanguageWorkedWith  \
# 0                         JavaScript;Python;HTML;CSS
# 1                       JavaScript;Python;Bash/Shell
# 2                                                NaN
# 3   C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell
# 4                 C;C++;Java;Matlab;R;SQL;Bash/Shell
# 5         Java;JavaScript;Python;TypeScript;HTML;CSS
# 6                                JavaScript;HTML;CSS
# 7                     JavaScript;TypeScript;HTML;CSS
# 8  Assembly;CoffeeScript;Erlang;Go;JavaScript;Lua...
# 9                                                NaN
#
#                   LastNewJob  \
# 0       Less than a year ago
# 1      More than 4 years ago
# 2       Less than a year ago
# 3       Less than a year ago
# 4  Between 1 and 2 years ago
# 5  Between 2 and 4 years ago
# 6       Less than a year ago
# 7       Less than a year ago
# 8  Between 2 and 4 years ago
# 9                        NaN
#
#                                          Methodology MilitaryUS OpenSource  \
# 0                                        Agile;Scrum        NaN         No
# 1                                                NaN        NaN        Yes
# 2                                                NaN        NaN        Yes
# 3                                 Agile;Kanban;Scrum         No         No
# 4  Evidence-based software engineering;Formal sta...        NaN         No
# 5                                              Agile        NaN         No
# 6                                        Agile;Scrum         No        Yes
# 7               Agile;Extreme programming (XP);Scrum        NaN        Yes
# 8  Agile;Evidence-based software engineering;Extr...         No        Yes
# 9                                                NaN        NaN        Yes
#
#   OperatingSystem                             PlatformDesireNextYear  \
# 0     Linux-based                           AWS;Azure;Linux;Firebase
# 1     Linux-based                                              Linux
# 2             NaN                                                NaN
# 3         Windows                                              Azure
# 4         Windows                  Arduino;Windows Desktop or Server
# 5     Linux-based                                              Linux
# 6           MacOS                                              Linux
# 7         Windows  Amazon Echo;Android;Apple Watch or Apple TV;AW...
# 8           MacOS                        AWS;Linux;Mac OS;Serverless
# 9             NaN                                                NaN
#
#                             PlatformWorkedWith                 RaceEthnicity  \
# 0                     AWS;Azure;Linux;Firebase   Black or of African descent
# 1                                        Linux  White or of European descent
# 2                                          NaN                           NaN
# 3                                        Azure  White or of European descent
# 4            Arduino;Windows Desktop or Server  White or of European descent
# 5                                        Linux  White or of European descent
# 6                                        Linux  White or of European descent
# 7                                 Azure;Heroku   Black or of African descent
# 8  Amazon Echo;AWS;iOS;Linux;Mac OS;Serverless  White or of European descent
# 9                                          NaN                           NaN
#
#    Respondent SalaryType                                    SelfTaughtTypes  \
# 0           1    Monthly  The official documentation and/or standards fo...
# 1           3     Yearly  The official documentation and/or standards fo...
# 2           4        NaN                                                NaN
# 3           5        NaN  The official documentation and/or standards fo...
# 4           7     Yearly  The official documentation and/or standards fo...
# 5           8        NaN  The official documentation and/or standards fo...
# 6           9     Yearly  The official documentation and/or standards fo...
# 7          10        NaN                                                NaN
# 8          11     Yearly  The official documentation and/or standards fo...
# 9          16        NaN                                                NaN
#
#           Student                                     UndergradMajor  \
# 0              No                          Mathematics or statistics
# 1              No  A natural science (ex. biology, chemistry, phy...
# 2              No  Computer science, computer engineering, or sof...
# 3              No  Computer science, computer engineering, or sof...
# 4  Yes, part-time  Computer science, computer engineering, or sof...
# 5              No  Computer science, computer engineering, or sof...
# 6              No  Computer science, computer engineering, or sof...
# 7              No  Computer science, computer engineering, or sof...
# 8              No  Fine arts or performing arts (ex. graphic desi...
# 9              No  Computer science, computer engineering, or sof...
#
#                                             UpdateCV     VersionControl  \
# 0     My job status or other personal status changed                Git
# 1                  I saw an employer’s advertisement     Git;Subversion
# 2                                                NaN                NaN
# 3                           A recruiter contacted me                Git
# 4     My job status or other personal status changed  Zip file back-ups
# 5  I did not receive an expected change in compen...                Git
# 6     My job status or other personal status changed                Git
# 7                  I saw an employer’s advertisement                Git
# 8     My job status or other personal status changed                Git
# 9                                                NaN                NaN
#
#         YearsCoding YearsCodingProf
# 0         3-5 years       3-5 years
# 1  30 or more years     18-20 years
# 2       24-26 years       6-8 years
# 3       18-20 years     12-14 years
# 4         6-8 years       0-2 years
# 5         6-8 years       3-5 years
# 6        9-11 years       0-2 years
# 7         0-2 years       3-5 years
# 8  30 or more years     21-23 years
# 9         0-2 years             NaN
