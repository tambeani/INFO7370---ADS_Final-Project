# %%
#import statements
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import seaborn as sns
import matplotlib as mpl
import squarify as sq
sns.set_style('whitegrid')
sns.set_palette('Paired')

import missingno as msno
from icecream import ic
import time
import os
import re
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import plotly.figure_factory as ff
from kaleido.scopes.plotly import PlotlyScope
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder 
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_selection import SelectKBest
import warnings
warnings.filterwarnings(action='ignore')
pd.options.display.max_columns = 100

# plotly settings and functions
scope = PlotlyScope(plotlyjs="https://cdn.plot.ly/plotly-latest.min.js")
pio.templates.default = 'plotly_white'

# %% [markdown]
# # READING THE DATASET

# %%
survey=pd.read_csv('.\dataset\survey_dropped_columns.csv')

# %%
survey.shape
# Out:
# (98855, 74)

# %%
survey.head()
# Out:
#                  Age  AgreeDisagree1  AgreeDisagree2  \
# 0  25 - 34 years old  Strongly agree  Strongly agree
# 1  35 - 44 years old           Agree           Agree
# 2                NaN             NaN             NaN
# 3  35 - 44 years old        Disagree        Disagree
# 4  18 - 24 years old  Strongly agree           Agree
#
#                AgreeDisagree3  AssessBenefits1  AssessBenefits10  \
# 0  Neither Agree nor Disagree              NaN               NaN
# 1  Neither Agree nor Disagree              1.0               2.0
# 2                         NaN              NaN               NaN
# 3           Strongly disagree              NaN               NaN
# 4           Strongly disagree              1.0               9.0
#
#    AssessBenefits11  AssessBenefits2  AssessBenefits3  AssessBenefits4  \
# 0               NaN              NaN              NaN              NaN
# 1               8.0              5.0              3.0              7.0
# 2               NaN              NaN              NaN              NaN
# 3               NaN              NaN              NaN              NaN
# 4               6.0             10.0              2.0              4.0
#
#    AssessBenefits5  AssessBenefits6  AssessBenefits7  AssessBenefits8  \
# 0              NaN              NaN              NaN              NaN
# 1             10.0              4.0             11.0              9.0
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              8.0              3.0             11.0              7.0
#
#    AssessBenefits9  AssessJob1  AssessJob10  AssessJob2  AssessJob3  \
# 0              NaN        10.0          6.0         7.0         8.0
# 1              6.0         1.0          9.0         7.0        10.0
# 2              NaN         NaN          NaN         NaN         NaN
# 3              NaN         NaN          NaN         NaN         NaN
# 4              5.0         8.0          9.0         5.0         7.0
#
#    AssessJob4  AssessJob5  AssessJob6  AssessJob7  AssessJob8  AssessJob9  \
# 0         1.0         2.0         5.0         3.0         4.0         9.0
# 1         8.0         2.0         5.0         4.0         3.0         6.0
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         1.0         2.0         6.0         4.0         3.0        10.0
#
#                    CareerSatisfaction  \
# 0                 Extremely satisfied
# 1  Neither satisfied nor dissatisfied
# 2                Moderately satisfied
# 3               Slightly dissatisfied
# 4                Moderately satisfied
#
#                                   CommunicationTools  \
# 0                                              Slack
# 1  Confluence;Office / productivity suite (Micros...
# 2                                                NaN
# 3                                                NaN
# 4  Office / productivity suite (Microsoft Office,...
#
#                 CompanySize  ConvertedSalary         Country  \
# 0        20 to 99 employees              NaN           Kenya
# 1  10,000 or more employees          70841.0  United Kingdom
# 2        20 to 99 employees              NaN   United States
# 3      100 to 499 employees              NaN   United States
# 4  10,000 or more employees          21426.0    South Africa
#
#                       Currency CurrencySymbol  \
# 0                          NaN            KES
# 1  British pounds sterling (£)            GBP
# 2                          NaN            NaN
# 3             U.S. dollars ($)            NaN
# 4      South African rands (R)            ZAR
#
#                               DatabaseDesireNextYear  \
# 0  Redis;SQL Server;MySQL;PostgreSQL;Amazon RDS/A...
# 1                                         PostgreSQL
# 2                                                NaN
# 3  SQL Server;Microsoft Azure (Tables, CosmosDB, ...
# 4                          PostgreSQL;Oracle;IBM Db2
#
#                                   DatabaseWorkedWith Dependents  \
# 0  Redis;SQL Server;MySQL;PostgreSQL;Amazon RDS/A...        Yes
# 1                         Redis;PostgreSQL;Memcached        Yes
# 2                                                NaN        NaN
# 3  SQL Server;Microsoft Azure (Tables, CosmosDB, ...         No
# 4               SQL Server;PostgreSQL;Oracle;IBM Db2        Yes
#
#                                              DevType  \
# 0                               Full-stack developer
# 1  Database administrator;DevOps specialist;Full-...
# 2           Engineering manager;Full-stack developer
# 3                               Full-stack developer
# 4  Data or business analyst;Desktop or enterprise...
#
#                                       EducationTypes          Employment  \
# 0  Taught yourself a new language, framework, or ...  Employed part-time
# 1  Taught yourself a new language, framework, or ...  Employed full-time
# 2                                                NaN  Employed full-time
# 3  Completed an industry certification program (e...  Employed full-time
# 4  Taken a part-time in-person course in programm...  Employed full-time
#
#                                      FormalEducation  FrameworkDesireNextYear  \
# 0           Bachelor’s degree (BA, BS, B.Eng., etc.)             Django;React
# 1           Bachelor’s degree (BA, BS, B.Eng., etc.)                    React
# 2                                   Associate degree                      NaN
# 3           Bachelor’s degree (BA, BS, B.Eng., etc.)  Angular;.NET Core;React
# 4  Some college/university study without earning ...                      NaN
#
#   FrameworkWorkedWith Gender  \
# 0        Django;React   Male
# 1              Django   Male
# 2                 NaN    NaN
# 3                 NaN   Male
# 4                 NaN   Male
#
#                                        HopeFiveYears  HoursComputer  \
# 0  Working as a founder or co-founder of my own c...   9 - 12 hours
# 1  Working in a different or more specialized tec...    5 - 8 hours
# 2  Working as a founder or co-founder of my own c...            NaN
# 3  Working as a founder or co-founder of my own c...   9 - 12 hours
# 4  Working in a different or more specialized tec...  Over 12 hours
#
#                                           IDE  JobEmailPriorities1  \
# 0               Komodo;Vim;Visual Studio Code                  5.0
# 1          IPython / Jupyter;Sublime Text;Vim                  1.0
# 2                                         NaN                  NaN
# 3            Visual Studio;Visual Studio Code                  NaN
# 4  Notepad++;Visual Studio;Visual Studio Code                  7.0
#
#    JobEmailPriorities2  JobEmailPriorities3  JobEmailPriorities4  \
# 0                  6.0                  7.0                  2.0
# 1                  3.0                  4.0                  5.0
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  3.0                  6.0                  2.0
#
#    JobEmailPriorities5  JobEmailPriorities6  JobEmailPriorities7  \
# 0                  1.0                  4.0                  3.0
# 1                  2.0                  6.0                  7.0
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  1.0                  4.0                  5.0
#
#                       JobSatisfaction  \
# 0                 Extremely satisfied
# 1             Moderately dissatisfied
# 2                Moderately satisfied
# 3  Neither satisfied nor dissatisfied
# 4                  Slightly satisfied
#
#                                      JobSearchStatus  \
# 0  I’m not actively looking, but I am open to new...
# 1                    I am actively looking for a job
# 2  I’m not actively looking, but I am open to new...
# 3  I’m not actively looking, but I am open to new...
# 4  I’m not actively looking, but I am open to new...
#
#                              LanguageDesireNextYear  \
# 0                        JavaScript;Python;HTML;CSS
# 1                                         Go;Python
# 2                                               NaN
# 3  C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell
# 4              Assembly;C;C++;Matlab;SQL;Bash/Shell
#
#                                  LanguageWorkedWith  \
# 0                        JavaScript;Python;HTML;CSS
# 1                      JavaScript;Python;Bash/Shell
# 2                                               NaN
# 3  C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell
# 4                C;C++;Java;Matlab;R;SQL;Bash/Shell
#
#                   LastNewJob  \
# 0       Less than a year ago
# 1      More than 4 years ago
# 2       Less than a year ago
# 3       Less than a year ago
# 4  Between 1 and 2 years ago
#
#                                          Methodology MilitaryUS OpenSource  \
# 0                                        Agile;Scrum        NaN         No
# 1                                                NaN        NaN        Yes
# 2                                                NaN        NaN        Yes
# 3                                 Agile;Kanban;Scrum         No         No
# 4  Evidence-based software engineering;Formal sta...        NaN         No
#
#   OperatingSystem             PlatformDesireNextYear  \
# 0     Linux-based           AWS;Azure;Linux;Firebase
# 1     Linux-based                              Linux
# 2             NaN                                NaN
# 3         Windows                              Azure
# 4         Windows  Arduino;Windows Desktop or Server
#
#                   PlatformWorkedWith                 RaceEthnicity  \
# 0           AWS;Azure;Linux;Firebase   Black or of African descent
# 1                              Linux  White or of European descent
# 2                                NaN                           NaN
# 3                              Azure  White or of European descent
# 4  Arduino;Windows Desktop or Server  White or of European descent
#
#    Respondent SalaryType                                    SelfTaughtTypes  \
# 0           1    Monthly  The official documentation and/or standards fo...
# 1           3     Yearly  The official documentation and/or standards fo...
# 2           4        NaN                                                NaN
# 3           5        NaN  The official documentation and/or standards fo...
# 4           7     Yearly  The official documentation and/or standards fo...
#
#           SexualOrientation         Student  \
# 0  Straight or heterosexual              No
# 1  Straight or heterosexual              No
# 2                       NaN              No
# 3  Straight or heterosexual              No
# 4  Straight or heterosexual  Yes, part-time
#
#                                       UndergradMajor  \
# 0                          Mathematics or statistics
# 1  A natural science (ex. biology, chemistry, phy...
# 2  Computer science, computer engineering, or sof...
# 3  Computer science, computer engineering, or sof...
# 4  Computer science, computer engineering, or sof...
#
#                                          UpdateCV     VersionControl  \
# 0  My job status or other personal status changed                Git
# 1               I saw an employer’s advertisement     Git;Subversion
# 2                                             NaN                NaN
# 3                        A recruiter contacted me                Git
# 4  My job status or other personal status changed  Zip file back-ups
#
#         YearsCoding YearsCodingProf
# 0         3-5 years       3-5 years
# 1  30 or more years     18-20 years
# 2       24-26 years       6-8 years
# 3       18-20 years     12-14 years
# 4         6-8 years       0-2 years

# %% [markdown]
# # FINDING MISSING VALUES

# %%
def paste_px_format(figure, **kwargs):
 #Updates Layout of the Figure with custom setting
    return figure.update_layout(**kwargs,
        font={'color': 'Gray', 'size': 10},
        width=780, margin={'pad': 10})


def save_figure(fig, name):
    with open(name, "wb") as f:
        save = scope.transform(fig, format="png")
        f.close()
        
        
def add_bubble(fig, **kwargs):
#Creates shape ontop of the figure
    return fig.add_shape(
        type="circle",
        line_color="white", 
        fillcolor="orange",
        opacity=0.6,
        xref='paper', yref='paper',
        x0=0.5, y0=0.6)


def prepare_data_salary(df, col)-> pd.DataFrame:
   
   # Returns a cross tab of selected for col parameter as a pandas dataframe.

    df_concat = pd.concat(
        [df[col], survey['CompTotal']], axis=1)\
        .dropna()
    
    df_concat['salary_cat'] = pd.qcut(
        df_concat['CompTotal'], 5, labels=[
        "Low(<10,000)", "Low-Med(10k-49k)",
        "Medium(49k-85k)", "High(85k-150k)",
        "Very High(150<)"])
    
    crosstab = pd.crosstab(
        df_concat[col],
        df_concat['salary_cat'])
    
    return crosstab


def get_files():
    for dirname, _, filenames in os.walk('/kaggle/input'):
        for filename in filenames:
            return (os.path.join(dirname, filename))

# %%
def missing_bar()-> go.Figure:
#Plots Missing Data for Whole Dataset
    title = 'Survey <b>Missing</b> Data by Features'
    
    # counts missing data
    missing_data = survey.isna().sum()
    missing_data = missing_data.to_frame().reset_index().rename(
        columns={'index': 'data_cols', 0: 'counts'})
    missing_data = missing_data.sort_values(by='counts', ascending=False)
    missing_perc = np.round(
        (survey.isna().sum().sum() / survey.size) * 100, 2)
    
    # figure colors
    colors = ['Gray'] * len(missing_data)
    colors[:10] = ['Orange']
    
    
    # create figure
    fig = go.Figure()
    for labels, values\
    in zip(missing_data.data_cols.to_list(), missing_data.counts):
    
        fig.add_trace(go.Bar(
            y=[labels],
            x=[values],
            name=labels,
            orientation='h'))
    
    # tweaking the layout
    fig.update_traces(marker_color=colors)
    fig.update_xaxes(title='Missing Counts')
    fig.update_yaxes(title='Features', tickmode='linear')
    
    fig.add_annotation(xref='paper', yref='paper',
        x=0.71, y=0.70, text=f"""
            {missing_perc}%""",
        font={'size': 20, 'color': 'White'},
        showarrow=False)
    
    fig.add_annotation(xref='paper', yref='paper',
        x=0.68, y=0.67, text=f"""Missing""",
        font={'size': 15, 'color': 'Gray'},
        showarrow=False)
    
    add_bubble(fig)

    return paste_px_format(
        fig, title=title, height=1000, showlegend=False)

# %%
#Displaying the missing values
missing_bar()
# Out:
# <div>                            <div id="c86d2c4b-52cb-44c4-b6d2-11089d7b949b" class="plotly-graph-div" style="height:1000px; width:780px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c86d2c4b-52cb-44c4-b6d2-11089d7b949b")) {                    Plotly.newPlot(                        "c86d2c4b-52cb-44c4-b6d2-11089d7b949b",                        [{"name":"MilitaryUS","orientation":"h","x":[83074],"y":["MilitaryUS"],"type":"bar","marker":{"color":["Orange","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray"]}},{"name":"JobEmailPriorities3","orientation":"h","x":[52642],"y":["JobEmailPriorities3"],"type":"bar","marker":{"color":["Orange","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray"]}},{"name":"JobEmailPriorities6","orientation":"h","x":[52642],"y":["JobEmailPriorities6"],"type":"bar","marker":{"color":["Orange","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray"]}},{"name":"JobEmailPriorities1","orientation":"h","x":[52642],"y":["JobEmailPriorities1"],"type":"bar","marker":{"color":["Orange","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray"]}},{"name":"JobEmailPriorities2","orientation":"h","x":[52642],"y":["JobEmailPriorities2"],"type":"bar","marker":{"color":["Orange","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray"]}},{"name":"JobEmailPriorities4","orientation":"h","x":[52642],"y":["JobEmailPriorities4"],"type":"bar","marker":{"color":["Orange","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray","Gray"]}},{"nam ...

# %%
#converting to percentage
total = survey.isnull().sum().sort_values(ascending = False)
percent = (survey.isnull().sum()/survey.isnull().count()*100).sort_values(ascending = False)
tmp = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])

#plotting the data
def plot_missing_data(start, end, text):
    tmp1 = tmp[start:end]
    plt.figure(figsize = (16,4))
    plt.title('Missing data - percents of missing data (part %s)' % text)
    s = sns.barplot(x=tmp1.index,y=tmp1['Percent'])
    s.set_xticklabels(s.get_xticklabels(),rotation=90)
    plt.show()    
    
#displaying the percentage of missing values
plot_missing_data(1,65,"I")

# %%
plot_missing_data(66,129,"II")

# %%
# sexuality values to dataframe
sexuality = survey['SexualOrientation'].value_counts().to_frame().T 

# wrangle data
sexuality_hetero = sexuality['Straight or heterosexual'].to_frame()
sexuality_lgbtq = sexuality.iloc[:, 2:]
sexuality_lgbtq = sexuality_lgbtq.sum(axis=1)\
    .to_frame()\
    .rename(columns={0: 'LGBTQ+'})

# prepare data for plot
sexuality = pd.concat([sexuality_hetero, sexuality_lgbtq], axis=1)

# %%
def plot_donut():
    
    # counts missing data
    missing_data = survey.isna().sum()
    missing_data = missing_data.to_frame().reset_index().rename(
        columns={'index': 'data_cols', 0: 'counts'})
    missing_data = missing_data.sort_values(by='counts', ascending=False)
    missing_perc = np.round(
        (survey.isna().sum().sum() / survey.size) * 100, 2)
    
    # figure colors
    colors = ['Gray'] * len(missing_data)
    colors[:10] = ['Orange']
    
    # figure colors
    labels = ['Heterosexual','LGBTQ+']
    
    # explosion
    explode = (0.05, 0.05)
    
    # Pie Chart
    plt.pie(sexuality.iloc[0,:], colors=colors, labels=labels,
        autopct='%1.1f%%', pctdistance=0.85,
        explode=explode)
    
    # draw circle
    centre_circle = plt.Circle((0, 0), 0.50, fc='white')
    fig = plt.gcf()

    # Adding Circle in Pie chart
    fig.gca().add_artist(centre_circle)

    # Adding Title of chart
    plt.title('Sexuality distribution for Survey')

    # Displaying Chart
    plt.show()

# %%
plot_donut()

# %% [markdown]
# ## HELPER FUNCTIONS

# %%
#defining the functions
def plot_categorical_count(survey, column, title='', limit=2, xtick_rotation='horizontal'):
    column_count = survey[column].value_counts()[:limit]
    
    fig = plt.figure(figsize=(14, 8))
    sns.barplot(x=column_count.index, y=column_count.values, palette='Paired')
    sns.despine(left=True)
    plt.title(title, fontsize=16)
    plt.xticks(rotation=xtick_rotation)

    #plotting heatmap
def plot_heatmap(survey, variable):
    l = []
    for name, group in top10_df.groupby('Country'):
        dff = pd.DataFrame(group[variable].value_counts() / group[variable].count()) 
        dff['Country'] = name
        dff['rate'] = dff.index
        l.append(dff)
    fig = plt.figure(figsize=(14, 8))
    df_2 = pd.concat(l)
    dff = df_2.pivot_table(index='Country', columns='rate')
    sns.heatmap(dff, cmap="YlGnBu", linewidths=.3)

# %% [markdown]
# ## SALARY DISTRIBUTION

# %%
plt.figure(figsize=(14, 12))
top_10_list = list(survey['Country'].value_counts()[:10].index)


#limiting results to top 10 for clarifiation
df_top10 = survey.where(survey['Country'].isin(top_10_list))

#plotting the data
sns.boxplot(data=df_top10, x='ConvertedSalary', y='Country', palette='Paired')
plt.title('Salary Distribution in the Top 10 Countries', fontsize=16)
sns.despine(left=True)

# %% [markdown]
# # YEARS CODING PROFESSIONALLY W.R.T. COUNTRIES

# %%
# Defining figure size
fig, axes = plt.subplots(10, 1, figsize=(14, 34))

for ax, country in zip(axes, top_10_list):
    data = survey[survey['Country'] == country]
    sns.countplot(data=data, x='YearsCodingProf', palette='Paired', ax=ax, order=data['YearsCodingProf'].value_counts().index)
    ax.set_title('Years coding professionally in {}'.format(country), fontsize=16)
    sns.despine(left=True)
    #
plt.subplots_adjust(hspace=.6)

# %% [markdown]
# # EMPLOYMENT STATUS OF DEVELOPERS

# %%
temp = survey.Employment.dropna().value_counts()
d = pd.DataFrame({'labels': temp.index,
                   'values': temp.values})
d = d.set_index('labels')
d.plot(kind='pie',autopct="%0.2f", figsize=(10,10), subplots=True)
# Out:
# array([<AxesSubplot:ylabel='values'>], dtype=object)

# %% [markdown]
# # MAIN FIELD STUDY OF DEVELOPERS

# %%
survey.UndergradMajor.dropna().value_counts().plot(kind='pie', autopct='%0.2f', figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='UndergradMajor'>

# %% [markdown]
# ## MOST REPRESENTED COUNTRIES

# %%
country = survey.groupby('Country').count()[['Respondent']].sort_values(by=['Respondent'], ascending=False).dropna().head(45)
# determining paramenters
fig = plt.gcf()
ax = fig.add_subplot()
fig.set_size_inches(20, 10)
norm = mpl.colors.Normalize(vmin=min(country.Respondent), vmax=max(country.Respondent))
colors = [mpl.cm.YlGnBu(norm(value)) for value in country.Respondent]

# plotting the squareplot
sq.plot(label=country.index,sizes=country.Respondent,color = colors, alpha=.8)
plt.axis('off')
plt.title('Countries from where overall respondents come from')
plt.show()

# %% [markdown]
# ### ANNUAL SALARY(USD) OVERALL DIST.

# %%
sal1 = survey[survey['Employment']=='Employed full-time']
sal1 = sal1.dropna(subset=['ConvertedSalary'])
fig,ax = plt.subplots(1,2, figsize=(20,10))

a = sns.distplot(sal1.ConvertedSalary, kde=False, ax=ax[0],axlabel = 'Annual Salary in USD')
a.set_ylabel('Frequency Count')
a.set_title('Annual Salary in USD - Distribution')
b = sns.distplot(sal1.ConvertedSalary,kde=False, ax=ax[1], axlabel = 'Log of Annual Salary in USD')
b.set_xscale('log')
b.set_ylabel('Frequency Count')
b.set_title('with Log')
# Out:
# Text(0.5, 1.0, 'with Log')

# %% [markdown]
# ### ANNUAL SALARY DIST. BY COUNTRY

# %%
countries_salary = survey[survey['Employment']=='Employed full-time']
countries_salary['count'] = countries_salary.groupby('Country')['Respondent'].transform('count')
countries_salary = countries_salary[countries_salary['count']>500]

# %%
fig, ax =  plt.subplots(figsize=(25,18))
ax =sns.violinplot(x=countries_salary.ConvertedSalary, y=countries_salary.Country, data = countries_salary, scale="width", palette="Set2")
ax.set_ylabel('Countries')
ax.set_title('Annual Salary in USD - Distribution by Country - More than 500 respondents')
# Out:
# Text(0.5, 1.0, 'Annual Salary in USD - Distribution by Country - More than 500 respondents')

# %% [markdown]
# ### IDE PREFERENCE

# %%
ide = survey[['IDE']]

#different kinds of IDEs
i = ide['IDE'].str.split(';').apply(pd.Series, 1).stack()
i.index = i.index.droplevel(-1) 
i.name = 'NewIDE'
ide = ide.join(i)

#plotting of IDE preferences
sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 15))
ax = sns.countplot(y="NewIDE", data=ide, order = ide['NewIDE'].value_counts().index ,palette="Set2" )
plt.ylabel('IDE')
plt.title('IDE Preference')
plt.tight_layout()

# %% [markdown]
# By Gender

# %%
#gender bifurcation
ide_gen = survey.filter(items=['IDE', 'Gender'])
ide_gen = ide_gen.dropna(subset=['IDE'])
ide_gen = ide_gen[(ide_gen['Gender'] == 'Female') | (ide_gen['Gender']=='Male')]


i = ide_gen['IDE'].str.split(';').apply(pd.Series, 1).stack()
i.index = i.index.droplevel(-1) 
i.name = 'IDE_NEW'
ide_gen = ide_gen.join(i)

#plotting wrt bifurcation
sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 15))
ax = sns.countplot(y="IDE_NEW", hue="Gender", data=ide_gen, order = ide_gen['IDE_NEW'].value_counts().index ,palette="Set3" )
plt.xscale("log")
plt.ylabel('IDE Preferences')
plt.title('IDE Preferences by Gender')
plt.tight_layout()

# %% [markdown]
# ### LANGUAGES USED FOR EXTENSIVE DEVELOPMENT WORK

# %%
lang = survey[['LanguageWorkedWith']]
lang = lang.dropna(subset=['LanguageWorkedWith'])

#generating different kinds of languages worked with
l= lang['LanguageWorkedWith'].str.split(';').apply(pd.Series, 1).stack()
l.index = l.index.droplevel(-1) 
l.name = 'NewLang'
lang = lang.join(l)

#plotting wrt languages preference
sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 15))
ax = sns.countplot(y="NewLang", data=lang, order = lang['NewLang'].value_counts().index ,palette="Set2" )
plt.ylabel('Languages')
plt.xlabel('Count')
plt.title('LanguageWorkedWith Preference')
plt.tight_layout()

# %% [markdown]
# ### FRAMEWORK WORKED WITH

# %%
framework = survey[['FrameworkWorkedWith']]
framework = framework.dropna(subset=['FrameworkWorkedWith'])

# Determining the frameworks worked with
f= framework['FrameworkWorkedWith'].str.split(';').apply(pd.Series, 1).stack()
f.index = f.index.droplevel(-1) 
f.name = 'NewFrameworkWorkedWith'
framework = framework.join(f)

#plotting wrt frameworks preference
sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 15))
ax = sns.countplot(y="NewFrameworkWorkedWith", data=framework, order = framework['NewFrameworkWorkedWith'].value_counts().index ,palette="Set2" )
plt.ylabel('Frameworks')
plt.xlabel('Count')
plt.title('FrameworkWorkedWith Preferences')
plt.tight_layout()

# %% [markdown]
# By Gender

# %%
#gender bifurcatiom
framework_gen = survey.filter(items=['FrameworkWorkedWith', 'Gender'])
framework_gen = framework_gen.dropna(subset=['FrameworkWorkedWith'])
framework_gen = framework_gen[(framework_gen['Gender'] == 'Female') | (framework_gen['Gender']=='Male')]

f= framework_gen['FrameworkWorkedWith'].str.split(';').apply(pd.Series, 1).stack()
f.index = f.index.droplevel(-1) 
f.name = 'NewFramework'
framework_gen = framework_gen.join(f)

# plotting wrt bifuraction
sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 15))
ax = sns.countplot(y="NewFramework", hue="Gender", data=framework_gen, order = framework_gen['NewFramework'].value_counts().index ,palette="Set2" )
plt.xscale("log")
plt.ylabel('Framework')
plt.xlabel('Count')
plt.title('FrameworkWorkedWith - by Gender')
plt.tight_layout()
